# %%
from gym import Env
from gym.spaces import Discrete, Box
import numpy as np
import random

# %%
baseline = []  #packets sent in baseline
drl = []       #packets sent in DRL  
power_baseline = []
power_drl = []
Network_energy_drl=[]
Network_energy_baseline=[]

# %%
# import matplotlib.pyplot as plt
# import numpy as np

# X = np.array([i for i in range(1000)])
# y = np.array(baseline_power)
# z = np.array(drl_power)


# plt.plot(X, y, color='r', label='Baseline model')
# plt.plot(X, z, color='g', label='DRL based model')
  
# # Naming the x-axis, y-axis and the whole graph

# plt.xlabel("Episodes")
# plt.ylabel("Power Available")
# plt.title("Battery Drain w.r.to Baseline and DRL")
  
# # Adding legend, which helps us recognize the curve according to it's color
# plt.legend()
# plt.xlim([0, 1200]) 
# plt.ylim([0, 18000]) 
# plt.rcParams["figure.figsize"] = (14,7)
# # To load the display window
# plt.show()

# %%
class Wireless_Env_Baseline(Env):
    def __init__(self):
        
        #Packet Generation Rates calculated from Auto-Regression Model
        self.pgr = [1, 1, 1, 1, 1, 1, 1, 1]
        
        #These are packet queues for each sensor
        self.pulse = []
        self.heart_rate = []
        self.temperature = []
        self.diabetes = []
        self.spo2 = []
        self.ibi = []
        self.eda = []
        self.acc = []
      
        
        #Total initial power
        self.power = 4        
        
        
        #Step count for each episode. It can be changed as per requirement.
        self.count = 1000
        
        #self.sensors = {0 : "Pulse", 1 : "Heart Rate", 2 : "Temprature", 3 : "Diabetes",  : "SpO2", 5 : "EDA", 6 : "IBI", 7 : "ACC"}
                
        # Actions we can take ---> we can select any of 8 sensors for packet transmission.
        self.action_space = Discrete(8)
        
        
        #initial timestamp (Optional---> I have used it for testing purpose.)
        self.time_stamp = 1
        
        #Set the network length(Will update the battery power,,, We can update here the minimum battery sensor)
        self.life = 1000        
        
        #Initial number of packets in queues
        self.state = 0        
        
        
        #This is observation space..will take any random value( Just for model shake...No use in our case.)
        self.observation_space = Box(low=np.array([0]), high=np.array([100]))
    
    
    #calculating reward based on our reward function.
    def get_reward(self, packet_gen_prob, self_queue, others_queue):
        #print("In Reward")
        reward_ = ((len(self_queue) * packet_gen_prob) + 1) / (others_queue - len(self_queue) + 1) + .25
        return reward_
     
        
    #This is crucial function. It defines how the state is changing after each selection. Every update is happening here.    
    def state_change(self): 
        
       
        
        #In baseline...adding 1 packet into each sensor queue as each sensor is sensing 1 packet per step.
        self.ibi.append(1)
        self.eda.append(1)        
        self.diabetes.append(1)        
        self.heart_rate.append(1)
        self.acc.append(1)       
        self.temperature.append(1)        
        self.pulse.append(1)       
        self.spo2.append(1)
            
        
    
    def step(self, action):       
        
        #for testing.
        self.count -= 1
        
        #Power equation used here. Can be changed as per requirement.
        self.power -= (16.31 * 10e-9 * 256 + 1.97 * 10e-9 * 100 * 256)
        
        #Testing
        #print("Selected sensor is --> ", action)
        
        #Changing the state.
        self.state_change()
        
        total_pending_packets = len(self.pulse) + len(self.heart_rate) + len(self.temperature) + len(self.diabetes) + len(self.spo2) + len(self.ibi) + len(self.eda) + len(self.acc) 
        
        #print("total pending packets -----> ", total_pending_packets)
        
        
        #In this if else ladder, we are updating based on selected node.
        
        if(self.count > 0):
            baseline.append(total_pending_packets)
#             drl.append(len(self.pulse) + len(self.heart_rate) + len(self.temperature) + len(self.diabetes))
        
        if(self.power > 0):
            power_baseline.append(self.power)
        if(self.power <= 0):
            power_baseline.append(0)
        Network_energy_baseline.append(self.power)
        if action == 0:
            #print(" Sensor Queue size is ", len(self.pulse))
            if(len(self.pulse) == 0):
                reward = 0
            else:
                
                reward = self.get_reward(self.pgr[0], self.pulse, total_pending_packets)
                if(len(self.pulse) != 0):
                    self.pulse.pop()
        
        elif action == 1:
            #print(" Sensor Queue size is ", len(self.heart_rate))
            if(len(self.heart_rate) == 0):
                reward = 0
            else:
                
                reward = self.get_reward(self.pgr[1], self.heart_rate, total_pending_packets)
                if len(self.heart_rate) != 0:
                    self.heart_rate.pop()
        
        elif action == 2:
            #print(" Sensor Queue size is ", len(self.temperature))
            if len(self.temperature) == 0:
                reward = 0
            else:
                
                reward = self.get_reward(self.pgr[2], self.temperature, total_pending_packets)        
                if len(self.temperature) != 0:
                    self.temperature.pop()
            
        elif action == 3:
            #print(" Sensor Queue size is ", len(self.diabetes ) )
            if(len(self.diabetes) == 0):
                reward = 0
            else:
                
                reward = self.get_reward(self.pgr[3], self.diabetes, total_pending_packets)
                if len(self.diabetes) != 0:
                    self.diabetes.pop()
        
        elif action == 4:
            #print(" Sensor Queue size is ", len(self.spo2))
            if(len(self.spo2) == 0):
                reward = 0
            else:
                
                reward = self.get_reward(self.pgr[4], self.spo2, total_pending_packets)        
                if len(self.spo2) != 0:
                    self.spo2.pop()
        elif action == 5:
            #print(" Sensor Queue size is ",len(self.eda))
            if(len(self.eda) == 0):
                reward = 0
            else:
                
                reward = self.get_reward(self.pgr[5], self.eda, total_pending_packets)        
                if len(self.eda) != 0:
                    self.eda.pop()
        elif action == 6:
            #print(" Sensor Queue size is ", len(self.ibi))
            if(len(self.ibi) == 0):
                reward = 0
            else:
                
                reward = self.get_reward(self.pgr[6], self.ibi, total_pending_packets)        
                if len(self.ibi) != 0:
                    self.ibi.pop()
        else:
            #print(" Sensor Queue size is ",len(self.acc))
            if(len(self.acc) == 0):
                reward = 0
            else:
                
                reward = self.get_reward(self.pgr[7], self.acc, total_pending_packets)        
                if len(self.acc) != 0:
                    self.acc.pop()  
        
        
        #Reducing life by 1, here we can also use battery power. 
        self.life -= 1    
        
       
        
        if self.life <= 0: 
            done = True
        else:
            done = False   
        
        # Apply temperature noise
        #self.state += random.randint(-1,1)
        
        # Set placeholder for info
        info = {}
        
        # Return step information
        return self.state, reward, done, info

    def render(self):
        #For Visualization Purpose
        pass
    
    def reset(self):
        # Reset shower temperature
        self.state = 0
        # Reset shower time
        self.life = 1000
        
        #Reset all packet queues
        self.pulse = []
        self.heart_rate = []
        self.temperature = []
        self.diabetes = []
        self.spo2 = []
        self.ibi = []
        self.eda = []
        self.acc = []
        
        return self.state

# %%
#Here also, all parameters are same as Baseline Model apart from PGR.
class Wireless_Env_DRL(Env):
    def __init__(self):
        
        #Packet Generation Rates calculated from Auto-Regression Model
        self.pgr = [0.87, 0.069, 0.001, 0.631, 0.03, 0.974, 0.938, 0.159]
        
        self.pulse = []
        self.heart_rate = []
        self.temperature = []
        self.diabetes = []
        self.spo2 = []
        self.ibi = []
        self.eda = []
        self.acc = []
        
        self.power = [.5, .5, .5, .5, .5, .5, .5, .5]
        self.count = 1001
        #self.flag = 1
        #self.sensors = {0 : "Pulse", 1 : "Heart Rate", 2 : "Temprature", 3 : "Diabetes",  : "SpO2", 5 : "EDA", 6 : "IBI", 7 : "ACC"}
                
        # Actions we can take, down, stay, up
        self.action_space = Discrete(8)
        
        self.time_stamp = 1
        
        #Set the network length(Will update the battery power,,, We can update here the minimum battery sensor)
        self.life = 1000        
        
        #Initial number of packets in queues
        self.state = 0        
        
        self.observation_space = Box(low=np.array([0]), high=np.array([100]))
        
    def get_reward(self, packet_gen_prob, self_queue, others_queue):
        #print("In Reward")
        reward_ = (((len(self_queue) * packet_gen_prob) + 1) / (others_queue - len(self_queue) + 1) + .25)
        return reward_
        
    def state_change(self): 
        
        ts = self.time_stamp
        
        self.time_stamp += 1
        
        self.ibi.append(1)
        self.eda.append(1) 
        if ts % 2 == 0:
           self.diabetes.append(1)        
        
        if ts % 14 == 0:
            self.heart_rate.append(1)
        
        if ts % 6 == 0:
            self.acc.append(1)
        
        if ts % 1000 == 0:
            self.temperature.append(1)
            
        if ts % 11 == 0:
            self.pulse.append(1)            
            
        if ts % 30 == 0:
            self.spo2.append(1)
            
        
    
    def step(self, action):       
        
        self.count -= 1
        
        #Power function. But we will reduce power only when sensor is selected.
        p = (16.31 * 10e-9 * 256 + 1.97 * 10e-9 * 100 * 256)
        
        
        #print("Selected sensor is --> ", action)
        
        self.state_change()
        
        total_pending_packets = len(self.pulse) + len(self.heart_rate) + len(self.temperature) + len(self.diabetes) + len(self.spo2) + len(self.ibi) + len(self.eda) + len(self.acc) 
        
        #print("total pending packets -----> ", total_pending_packets)
        
        if(self.count > 0):
            
            drl.append(total_pending_packets)
            
        if(sum(self.power) > 0):
            power_drl.append(sum(self.power))
        
        Network_energy_drl.extend(self.power)
        if action == 0:
            #print(" Sensor Queue size is ", len(self.pulse))
            if(len(self.pulse) == 0):
                reward = 0
            else:
                if(self.power[0] - p > 0): #here I am reducing power if this sensor is selected. same for others as well.
                    self.power[0] -= p
                    #print(power)
                reward = self.get_reward(self.pgr[0], self.pulse, total_pending_packets)
                if(len(self.pulse) != 0):
                    self.pulse.pop()
        
        elif action == 1:
            #print(" Sensor Queue size is ", len(self.heart_rate))
            if(len(self.heart_rate) == 0):
                reward = 0
            else:
                if(self.power[1] - p > 0):
                    self.power[1] -= p
                reward = self.get_reward(self.pgr[1], self.heart_rate, total_pending_packets)
                if len(self.heart_rate) != 0:
                    self.heart_rate.pop()
        
        elif action == 2:
            #print(" Sensor Queue size is ", len(self.temperature))
            if len(self.temperature) == 0:
                reward = 0
            else:
                if(self.power[2] - p > 0):
                    self.power[2] -= p
                reward = self.get_reward(self.pgr[2], self.temperature, total_pending_packets)        
                if len(self.temperature) != 0:
                    self.temperature.pop()
            
        elif action == 3:
            #print(" Sensor Queue size is ", len(self.diabetes ) )
            if(len(self.diabetes) == 0):
                reward = 0
            else:
                if(self.power[3] - p > 0):
                    self.power[3] -= p
                reward = self.get_reward(self.pgr[3], self.diabetes, total_pending_packets)
                if len(self.diabetes) != 0:
                    self.diabetes.pop()
        
        elif action == 4:
            #print(" Sensor Queue size is ", len(self.spo2))
            if(len(self.spo2) == 0):
                reward = 0
            else:
                if(self.power[4] - p > 0):
                    self.power[4] -= p
                reward = self.get_reward(self.pgr[4], self.spo2, total_pending_packets)        
                if len(self.spo2) != 0:
                    self.spo2.pop()
        elif action == 5:
            #print(" Sensor Queue size is ",len(self.eda))
            if(len(self.eda) == 0):
                reward = 0
            else:
                if(self.power[5] - p > 0):
                    self.power[5] -= p
                reward = self.get_reward(self.pgr[5], self.eda, total_pending_packets)        
                if len(self.eda) != 0:
                    self.eda.pop()
        elif action == 6:
            #print(" Sensor Queue size is ", len(self.ibi))
            if(len(self.ibi) == 0):
                reward = 0
            else:
                if(self.power[6] - p > 0):
                    self.power[6] -= p
                reward = self.get_reward(self.pgr[6], self.ibi, total_pending_packets)        
                if len(self.ibi) != 0:
                    self.ibi.pop()
        else:
            #print(" Sensor Queue size is ",len(self.acc))
            if(len(self.acc) == 0):
                reward = 0
            else:
                if(self.power[7] - p > 0):
                    self.power[7] -= p
                reward = self.get_reward(self.pgr[7], self.acc, total_pending_packets)        
                if len(self.acc) != 0:
                    self.acc.pop()  
        
        
        
        self.life -= 1    
            
        if self.life <= 0: 
            done = True
        else:
            done = False   
        
        # Apply temperature noise
        #self.state += random.randint(-1,1)
        
        # Set placeholder for info
        info = {}
        
        # Return step information
        return self.state, reward, done, info

    def render(self):
        #For Visualization Purpose
        pass
    
    #This step resets the parameters after each 1000 steps. For training purpose. can be updated for battery life as well.
    def reset(self):
        # Reset shower temperature
        self.state = 0
        # Reset shower time
        self.life = 1000
        
        #Reset all packet queues
        self.pulse = []
        self.heart_rate = []
        self.temperature = []
        self.diabetes = []
        self.spo2 = []
        self.ibi = []
        self.eda = []
        self.acc = []
        
        return self.state

# %%
env_drl = Wireless_Env_DRL()
# Out:
# /usr/local/lib/python3.7/dist-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %%
env_bsl = Wireless_Env_Baseline()
# Out:
# /usr/local/lib/python3.7/dist-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %%
env_bsl.observation_space.sample()
# Out:
# array([96.919495], dtype=float32)

# %%
env_drl.observation_space.sample()
# Out:
# array([71.05866], dtype=float32)

# %%
 episodes = 10
 sco_drl = []
 for episode in range(1, episodes+1):
     state = env_drl.reset()
     done = False
     score = 0 
    
     while not done:
         #env.render()
         action = env_drl.action_space.sample()
         n_state, reward, done, info = env_drl.step(action)
         score+=reward
     print('Episode:{} Reward:{}'.format(episode, score))
     sco_drl.append(score)
# Out:
# Episode:1 Reward:349.54727344129896
# Episode:2 Reward:360.64394253198634
# Episode:3 Reward:355.8371876822331
# Episode:4 Reward:357.5610175856082
# Episode:5 Reward:347.85794665782515
# Episode:6 Reward:340.2428187488734
# Episode:7 Reward:327.29616765046245
# Episode:8 Reward:324.7810367100896
# Episode:9 Reward:343.3053840984981
# Episode:10 Reward:352.57764045761473

# %%
 episodes = 10
 sco_bsl=[]
 for episode in range(1, episodes+1):
     state = env_bsl.reset()
     done = False
     score = 0 
    
     while not done:
         #env.render()
         action = env_bsl.action_space.sample()
         n_state, reward, done, info = env_bsl.step(action)
         score+=reward
     print('Episode:{} Reward:{}'.format(episode, score))
     sco_drl.append(score)
# Out:
# Episode:1 Reward:393.9158701954011
# Episode:2 Reward:393.89496487273715
# Episode:3 Reward:393.926887055047
# Episode:4 Reward:394.05180377123577
# Episode:5 Reward:393.85808160420646
# Episode:6 Reward:393.7032283836826
# Episode:7 Reward:393.93482136707706
# Episode:8 Reward:393.7494541594191
# Episode:9 Reward:393.9048926552631
# Episode:10 Reward:393.70660544762353

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#A = np.array(sco_drl)

# %%
#pd.DataFrame(A).to_csv('/content/drive/MyDrive/Colab Notebooks/reward_drl_e4.csv')

# %%
import numpy as np
import tensorflow
import keras
from keras.models import Sequential
from keras.layers import Dense, Flatten
from tensorflow.keras.optimizers import Adam
model = keras.Sequential()

# %%
states = env_bsl.observation_space.shape
actions = env_bsl.action_space.n

# %%
states = env_drl.observation_space.shape
actions = env_drl.action_space.n

# %%
env_drl.observation_space
# Out:
# Box(0.0, 100.0, (1,), float32)

# %%
env_bsl.observation_space
# Out:
# Box(0.0, 100.0, (1,), float32)

# %%
actions
# Out:
# 8

# %%
del model

# %%
def build_model(states, actions):
    model = keras.Sequential()
    
    model.add(Dense(32, activation='relu', input_shape=states))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(actions, activation='linear'))
    return model

# %%
model = build_model(states, actions)

# %%
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_9 (Dense)             (None, 32)                64
#
#  dense_10 (Dense)            (None, 64)                2112
#
#  dense_11 (Dense)            (None, 8)                 520
#
# =================================================================
# Total params: 2,696
# Trainable params: 2,696
# Non-trainable params: 0
# _________________________________________________________________

# %%
# !pip install keras-rl2
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: keras-rl2 in /usr/local/lib/python3.7/dist-packages (1.0.5)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.7/dist-packages (from keras-rl2) (2.8.2+zzzcolab20220527125636)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-rl2) (0.26.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-rl2) (57.4.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-rl2) (3.17.3)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-rl2) (1.6.3)
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-rl2) (14.0.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-rl2) (3.3.0)
# Requirement already satisfied: tensorflow-estimator<2.9,>=2.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-rl2) (2.8.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-rl2) (3.1.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-rl2) (1.1.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-rl2) (1.15.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-rl2) (4.2.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-rl2) (1.1.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-rl2) (0.2.0)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-rl2) (1.21.6)
# Requirement already satisfied: gast>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-rl2) (0.5.3)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-rl2) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-rl2) (1.46.3)
# Requirement already satisfied: flatbuffers>=1.12 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-rl2) (2.0)
# Requirement already satisfied: absl-py>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-rl2) (1.1.0)
# Requirement already satisfied: keras<2.9,>=2.8.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-rl2) (2.8.0)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-rl2) (2.8.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from astunparse>=1.6.0->tensorflow->keras-rl2) (0.37.1)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py>=2.9.0->tensorflow->keras-rl2) (1.5.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow->keras-rl2) (1.35.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow->keras-rl2) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow->keras-rl2) (3.3.7)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow->keras-rl2) (0.4.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow->keras-rl2) (1.8.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow->keras-rl2) (2.23.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow->keras-rl2) (0.6.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow->keras-rl2) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow->keras-rl2) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow->keras-rl2) (4.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow->keras-rl2) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow->keras-rl2) (4.11.4)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow->keras-rl2) (3.8.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow->keras-rl2) (0.4.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow->keras-rl2) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow->keras-rl2) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow->keras-rl2) (2022.5.18.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow->keras-rl2) (3.0.4)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow->keras-rl2) (3.2.0)

# %%
from rl.agents import DQNAgent
from rl.policy import BoltzmannQPolicy
from rl.memory import SequentialMemory

# %%
def build_agent(model, actions):
    policy = BoltzmannQPolicy()
    memory = SequentialMemory(limit=12000, window_length=1)
    dqn = DQNAgent(model=model, memory=memory, policy=policy, 
                  nb_actions=actions, nb_steps_warmup=10, target_model_update=1e-2)
    return dqn

# %%
#Run DRL based model
dqn = build_agent(model, actions)
dqn.compile(Adam(lr=1e-3), metrics=['mae'])
dqn.fit(env_drl, nb_steps=12000, visualize=False, verbose=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Training for 12000 steps ...
# Interval 1 (0 steps performed)
#     1/10000 [..............................] - ETA: 29:06 - reward: 0.0000e+00
# /usr/local/lib/python3.7/dist-packages/keras/engine/training_v1.py:2079: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# /usr/local/lib/python3.7/dist-packages/rl/memory.py:37: UserWarning: Not enough entries to sample without replacement. Consider increasing your warm-up phase to avoid oversampling!
#   warnings.warn('Not enough entries to sample without replacement. Consider increasing your warm-up phase to avoid oversampling!')
# 10000/10000 [==============================] - 109s 11ms/step - reward: 0.3726
# 10 episodes - episode_reward: 372.564 [351.724, 405.948] - loss: 0.111 - mae: 3.929 - mean_q: 4.553
#
# Interval 2 (10000 steps performed)
#  2000/10000 [=====>........................] - ETA: 1:15 - reward: 0.3973done, took 127.555 seconds

# %%
#sscores = dqn.test(env_drl, nb_episodes = 300, visualize = False)
# Out:
# Testing for 300 episodes ...
# Episode 1: reward: 257.677, steps: 1000
# Episode 2: reward: 257.009, steps: 1000
# Episode 3: reward: 257.679, steps: 1000
# Episode 4: reward: 257.427, steps: 1000
# Episode 5: reward: 257.747, steps: 1000
# Episode 6: reward: 257.846, steps: 1000
# Episode 7: reward: 257.656, steps: 1000
# Episode 8: reward: 257.791, steps: 1000
# Episode 9: reward: 257.668, steps: 1000
# Episode 10: reward: 257.678, steps: 1000
# Episode 11: reward: 257.741, steps: 1000
# Episode 12: reward: 258.013, steps: 1000
# Episode 13: reward: 257.066, steps: 1000
# Episode 14: reward: 257.582, steps: 1000
# Episode 15: reward: 257.763, steps: 1000
# Episode 16: reward: 257.359, steps: 1000
# Episode 17: reward: 257.766, steps: 1000
# Episode 18: reward: 257.809, steps: 1000
# Episode 19: reward: 257.664, steps: 1000
# Episode 20: reward: 257.774, steps: 1000
# Episode 21: reward: 258.003, steps: 1000
# Episode 22: reward: 257.669, steps: 1000
# Episode 23: reward: 257.577, steps: 1000
# Episode 24: reward: 257.344, steps: 1000
# Episode 25: reward: 257.355, steps: 1000
# Episode 26: reward: 257.676, steps: 1000
# Episode 27: reward: 257.805, steps: 1000
# Episode 28: reward: 257.630, steps: 1000
# Episode 29: reward: 257.772, steps: 1000
# Episode 30: reward: 257.654, steps: 1000
# Episode 31: reward: 257.666, steps: 1000
# Episode 32: reward: 257.731, steps: 1000
# Episode 33: reward: 258.003, steps: 1000
# Episode 34: reward: 257.644, steps: 1000
# Episode 35: reward: 257.247, steps: 1000
# Episode 36: reward: 257.659, steps: 1000
# Episode 37: reward: 257.319, steps: 1000
# Episode 38: reward: 257.734, steps: 1000
# Episode 39: reward: 257.782, steps: 1000
# Episode 40: reward: 257.645, steps: 1000
# Episode 41: reward: 257.760, steps: 1000
# Episode 42: reward: 257.990, steps: 1000
# Episode 43: reward: 257.659, steps: 1000
# Episode 44: reward: 257.569, steps: 1000
# Episode 45: reward: 257.997, steps: 1000
# Episode 46: reward: 257.020, steps: 1000
# Episode 47: reward: 257.572, steps: 1000
# Episode 48: reward: 257.734, steps: 1000
# Episode 49: reward: 257.598, steps: 1000
# Episode 50: reward: 257.746, steps: 1000
# Episode 51: reward: 257.637, steps: 1000
# Episode 52: reward: 257.650, steps: 1000
# Episode 53: reward: 257.719, steps: 1000
# Episode 54: reward: 257.992, steps: 1000
# Episode 55: reward: 257.636, steps: 1000
# Episode 56: reward: 257.885, steps: 1000
# Episode 57: reward: 257.323, steps: 1000
# Episode 58: reward: 257.266, steps: 1000
# Episode 59: reward: 257.663, steps: 1000
# Episode 60: reward: 257.750, steps: 1000
# Episode 61: reward: 257.619, steps: 1000
# Episode 62: reward: 257.743, steps: 1000
# Episode 63: reward: 257.973, steps: 1000
# Episode 64: reward: 257.648, steps: 1000
# Episode 65: reward: 257.559, steps: 1000
# Episode 66: reward: 257.988, steps: 1000
# Episode 67: reward: 257.588, steps: 1000
# Episode 68: reward: 257.237, steps: 1000
# Episode 69: reward: 257.630, steps: 1000
# Episode 70: reward: 257.546, steps: 1000
# Episode 71: reward: 257.714, steps: 1000
# Episode 72: reward: 257.610, steps: 1000
# Episode 73: reward: 257.631, steps: 1000
# Episode 74: reward: 257.704, steps: 1000
# Episode 75: reward: 257.978, steps: 1000
# Episode 76: reward: 257.626, steps: 1000
# Episode 77: reward: 257.876, steps: 1000
# Episode 78: reward: 257.974, steps: 1000
# Episode 79: reward: 256.931, steps: 1000
# Episode 80: reward: 257.559, steps: 1000
# Episode 81: reward: 257.679, steps: 1000
# Episode 82: reward: 257.586, steps: 1000
# Episode 83: reward: 257.717, steps: 1000
# Episode 84: reward: 257.954, steps: 1000
# Episode 85: reward: 257.631, steps: 1000
# Episode 86: reward: 257.547, steps: 1000
# Episode 87: reward: 257.976, steps: 1000
# Episode 88: reward: 257.580, steps: 1000
# Episode 89: reward: 257.874, steps: 1000
# Episode 90: reward: 257.294, steps: 1000
# Episode 91: reward: 257.474, steps: 1000
# Episode 92: reward: 257.643, steps: 1000
# Episode 93: reward: 257.578, steps: 1000
# Episode 94: reward: 257.604, steps: 1000
# Episode 95: reward: 257.688, steps: 1000
# Episode 96: reward: 257.962, steps: 1000
# Episode 97: reward: 257.615, steps: 1000
# Episode 98: reward: 257.865, steps: 1000
# Episode 99: reward: 257.965, steps: 1000
# Episode 100: reward: 257.468, steps: 1000
# Episode 101: reward: 257.224, steps: 1000
# Episode 102: reward: 257.574, steps: 1000
# Episode 103: reward: 257.534, steps: 1000
# Episode 104: reward: 257.685, steps: 1000
# Episode 105: reward: 257.922, steps: 1000
# Episode 106: reward: 257.612, steps: 1000
# Episode 107: reward: 257.533, steps: 1000
# Episode 108: reward: 257.963, steps: 1000
# Episode 109: reward: 257.570, steps: 1000
# Episode 110: reward: 257.865, steps: 1000
# Episode 111: reward: 257.941, steps: 1000
# Episode 112: reward: 257.138, steps: 1000
# Episode 113: reward: 257.538, steps: 1000
# Episode 114: reward: 257.526, steps: 1000
# Episode 115: reward: 257.572, steps: 1000
# Episode 116: reward: 257.666, steps: 1000
# Episode 117: reward: 257.943, steps: 1000
# Episode 118: reward: 257.600, steps: 1000
# Episode 119: reward: 257.852, steps: 1000
# Episode 120: reward: 257.954, steps: 1000
# Episode 121: reward: 257.460, steps: 1000
# Episode 122: reward: 257.860, steps: 1000
# Episode 123: reward: 257.239, steps: 1000
# Episode 124: reward: 257.463, steps: 1000
# Episode 125: reward: 257.614, steps: 1000
# Episode 126: reward: 257.882, steps: 1000
# Episode 127: reward: 257.586, steps: 1000
# Episode 128: reward: 257.516, steps: 1000
# Episode 129: reward: 257.946, steps: 1000
# Episode 130: reward: 257.559, steps: 1000
# Episode 131: reward: 257.854, steps: 1000
# Episode 132: reward: 257.932, steps: 1000
# Episode 133: reward: 257.723, steps: 1000
# Episode 134: reward: 257.203, steps: 1000
# Episode 135: reward: 257.454, steps: 1000
# Episode 136: reward: 257.520, steps: 1000
# Episode 137: reward: 257.639, steps: 1000
# Episode 138: reward: 257.911, steps: 1000
# Episode 139: reward: 257.584, steps: 1000
# Episode 140: reward: 257.835, steps: 1000
# Episode 141: reward: 257.943, steps: 1000
# Episode 142: reward: 257.450, steps: 1000
# Episode 143: reward: 257.852, steps: 1000
# Episode 144: reward: 257.872, steps: 1000
# Episode 145: reward: 257.127, steps: 1000
# Episode 146: reward: 257.510, steps: 1000
# Episode 147: reward: 257.810, steps: 1000
# Episode 148: reward: 257.554, steps: 1000
# Episode 149: reward: 257.494, steps: 1000
# Episode 150: reward: 257.927, steps: 1000
# Episode 151: reward: 257.545, steps: 1000
# Episode 152: reward: 257.841, steps: 1000
# Episode 153: reward: 257.921, steps: 1000
# Episode 154: reward: 257.714, steps: 1000
# Episode 155: reward: 257.838, steps: 1000
# Episode 156: reward: 257.118, steps: 1000
# Episode 157: reward: 257.448, steps: 1000
# Episode 158: reward: 257.568, steps: 1000
# Episode 159: reward: 257.870, steps: 1000
# Episode 160: reward: 257.557, steps: 1000
# Episode 161: reward: 257.816, steps: 1000
# Episode 162: reward: 257.926, steps: 1000
# Episode 163: reward: 257.439, steps: 1000
# Episode 164: reward: 257.841, steps: 1000
# Episode 165: reward: 257.863, steps: 1000
# Episode 166: reward: 257.712, steps: 1000
# Episode 167: reward: 257.175, steps: 1000
# Episode 168: reward: 257.705, steps: 1000
# Episode 169: reward: 257.502, steps: 1000
# Episode 170: reward: 257.467, steps: 1000
# Episode 171: reward: 257.895, steps: 1000
# Episode 172: reward: 257.528, steps: 1000
# Episode 173: reward: 257.824, steps: 1000
# Episode 174: reward: 257.909, steps: 1000
# Episode 175: reward: 257.704, steps: 1000
# Episode 176: reward: 257.830, steps: 1000
# Episode 177: reward: 257.700, steps: 1000
# Episode 178: reward: 257.113, steps: 1000
# Episode 179: reward: 257.464, steps: 1000
# Episode 180: reward: 257.799, steps: 1000
# Episode 181: reward: 257.525, steps: 1000
# Episode 182: reward: 257.790, steps: 1000
# Episode 183: reward: 257.907, steps: 1000
# Episode 184: reward: 257.425, steps: 1000
# Episode 185: reward: 257.828, steps: 1000
# Episode 186: reward: 257.852, steps: 1000
# Episode 187: reward: 257.703, steps: 1000
# Episode 188: reward: 257.804, steps: 1000
# Episode 189: reward: 257.370, steps: 1000
# Episode 190: reward: 257.430, steps: 1000
# Episode 191: reward: 257.415, steps: 1000
# Episode 192: reward: 257.855, steps: 1000
# Episode 193: reward: 257.506, steps: 1000
# Episode 194: reward: 257.805, steps: 1000
# Episode 195: reward: 257.895, steps: 1000
# Episode 196: reward: 257.692, steps: 1000
# Episode 197: reward: 257.819, steps: 1000
# Episode 198: reward: 257.691, steps: 1000
# Episode 199: reward: 257.697, steps: 1000
# Episode 200: reward: 257.129, steps: 1000
# Episode 201: reward: 257.694, steps: 1000
# Episode 202: reward: 257.473, steps: 1000
# Episode 203: reward: 257.758, steps: 1000
# Episode 204: reward: 257.875, steps: 1000
# Episode 205: reward: 257.408, steps: 1000
# Episode 206: reward: 257.811, steps: 1000
# Episode 207: reward: 257.840, steps: 1000
# Episode 208: reward: 257.692, steps: 1000
# Episode 209: reward: 257.797, steps: 1000
# Episode 210: reward: 258.024, steps: 1000
# Episode 211: reward: 257.095, steps: 1000
# Episode 212: reward: 257.344, steps: 1000
# Episode 213: reward: 257.784, steps: 1000
# Episode 214: reward: 257.479, steps: 1000
# Episode 215: reward: 257.779, steps: 1000
# Episode 216: reward: 257.878, steps: 1000
# Episode 217: reward: 257.675, steps: 1000
# Episode 218: reward: 257.807, steps: 1000
# Episode 219: reward: 257.680, steps: 1000
# Episode 220: reward: 257.689, steps: 1000
# Episode 221: reward: 257.749, steps: 1000
# Episode 222: reward: 257.359, steps: 1000
# Episode 223: reward: 257.401, steps: 1000
# Episode 224: reward: 257.687, steps: 1000
# Episode 225: reward: 257.834, steps: 1000
# Episode 226: reward: 257.386, steps: 1000
# Episode 227: reward: 257.792, steps: 1000
# Episode 228: reward: 257.826, steps: 1000
# Episode 229: reward: 257.681, steps: 1000
# Episode 230: reward: 257.786, steps: 1000
# Episode 231: reward: 258.015, steps: 1000
# Episode 232: reward: 257.677, steps: 1000
# Episode 233: reward: 257.009, steps: 1000
# Episode 234: reward: 257.679, steps: 1000
# Episode 235: reward: 257.427, steps: 1000
# Episode 236: reward: 257.747, steps: 1000
# Episode 237: reward: 257.846, steps: 1000
# Episode 238: reward: 257.656, steps: 1000
# Episode 239: reward: 257.791, steps: 1000
# Episode 240: reward: 257.668, steps: 1000
# Episode 241: reward: 257.678, steps: 1000
# Episode 242: reward: 257.741, steps: 1000
# Episode 243: reward: 258.013, steps: 1000
# Episode 244: reward: 257.066, steps: 1000
# Episode 245: reward: 257.582, steps: 1000
# Episode 246: reward: 257.763, steps: 1000
# Episode 247: reward: 257.359, steps: 1000
# Episode 248: reward: 257.766, steps: 1000
# Episode 249: reward: 257.809, steps: 1000
# Episode 250: reward: 257.664, steps: 1000
# Episode 251: reward: 257.774, steps: 1000
# Episode 252: reward: 258.003, steps: 1000
# Episode 253: reward: 257.669, steps: 1000
# Episode 254: reward: 257.577, steps: 1000
# Episode 255: reward: 257.344, steps: 1000
# Episode 256: reward: 257.355, steps: 1000
# Episode 257: reward: 257.676, steps: 1000
# Episode 258: reward: 257.805, steps: 1000
# Episode 259: reward: 257.630, steps: 1000
# Episode 260: reward: 257.772, steps: 1000
# Episode 261: reward: 257.654, steps: 1000
# Episode 262: reward: 257.666, steps: 1000
# Episode 263: reward: 257.731, steps: 1000
# Episode 264: reward: 258.003, steps: 1000
# Episode 265: reward: 257.644, steps: 1000
# Episode 266: reward: 257.247, steps: 1000
# Episode 267: reward: 257.659, steps: 1000
# Episode 268: reward: 257.319, steps: 1000
# Episode 269: reward: 257.734, steps: 1000
# Episode 270: reward: 257.782, steps: 1000
# Episode 271: reward: 257.645, steps: 1000
# Episode 272: reward: 257.760, steps: 1000
# Episode 273: reward: 257.990, steps: 1000
# Episode 274: reward: 257.659, steps: 1000
# Episode 275: reward: 257.569, steps: 1000
# Episode 276: reward: 257.997, steps: 1000
# Episode 277: reward: 257.020, steps: 1000
# Episode 278: reward: 257.572, steps: 1000
# Episode 279: reward: 257.734, steps: 1000
# Episode 280: reward: 257.598, steps: 1000
# Episode 281: reward: 257.746, steps: 1000
# Episode 282: reward: 257.637, steps: 1000
# Episode 283: reward: 257.650, steps: 1000
# Episode 284: reward: 257.719, steps: 1000
# Episode 285: reward: 257.992, steps: 1000
# Episode 286: reward: 257.636, steps: 1000
# Episode 287: reward: 257.885, steps: 1000
# Episode 288: reward: 257.323, steps: 1000
# Episode 289: reward: 257.266, steps: 1000
# Episode 290: reward: 257.663, steps: 1000
# Episode 291: reward: 257.750, steps: 1000
# Episode 292: reward: 257.619, steps: 1000
# Episode 293: reward: 257.743, steps: 1000
# Episode 294: reward: 257.973, steps: 1000
# Episode 295: reward: 257.648, steps: 1000
# Episode 296: reward: 257.559, steps: 1000
# Episode 297: reward: 257.988, steps: 1000
# Episode 298: reward: 257.588, steps: 1000
# Episode 299: reward: 257.237, steps: 1000
# Episode 300: reward: 257.630, steps: 1000

# %%
len(Network_energy_drl)
# Out:
# 96000

# %%
my_array = np.array(Network_energy_drl)

# %%
NTE=np.reshape(Network_energy_drl,(12000,8))

# %%
import pandas as pd

# %%
df=pd.DataFrame(NTE)

# %%
df
# Out:
#               0         1    2         3         4         5         6  \
# 0      0.500000  0.500000  0.5  0.500000  0.500000  0.500000  0.500000
# 1      0.500000  0.500000  0.5  0.500000  0.500000  0.500000  0.500000
# 2      0.500000  0.500000  0.5  0.500000  0.500000  0.500000  0.500000
# 3      0.500000  0.500000  0.5  0.500000  0.500000  0.500000  0.499454
# 4      0.500000  0.500000  0.5  0.500000  0.500000  0.500000  0.499454
# ...         ...       ...  ...       ...       ...       ...       ...
# 11995  0.000343  0.036930  0.5  0.000343  0.285393  0.000343  0.000343
# 11996  0.000343  0.036930  0.5  0.000343  0.285393  0.000343  0.000343
# 11997  0.000343  0.036930  0.5  0.000343  0.285393  0.000343  0.000343
# 11998  0.000343  0.036930  0.5  0.000343  0.285393  0.000343  0.000343
# 11999  0.000343  0.036384  0.5  0.000343  0.285393  0.000343  0.000343
#
#               7
# 0      0.500000
# 1      0.500000
# 2      0.500000
# 3      0.500000
# 4      0.500000
# ...         ...
# 11995  0.000343
# 11996  0.000343
# 11997  0.000343
# 11998  0.000343
# 11999  0.000343
#
# [12000 rows x 8 columns]

# %%
df.to_csv('/content/drive/MyDrive/Colab Notebooks/Engergy_e4.csv')

# %%
len(power_drl)
# Out:
# 12000

# %%
arti1 = np.array(power_drl)

# %%
pd.DataFrame(arti1).to_csv('/content/drive/MyDrive/Colab Notebooks/total_energy_e4.csv')

# %%
len(drl)
# Out:
# 1000

# %%
arti = np.array(drl)

# %%
pd.DataFrame(arti).to_csv('/content/drive/MyDrive/Colab Notebooks/packet_e4.csv')

# %%
#Run Baseline Model
dqn = build_agent(model, actions)
dqn.compile(Adam(lr=1e-3), metrics=['mae'])
dqn.fit(env_bsl, nb_steps=12000, visualize=False, verbose=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Training for 12000 steps ...
# Interval 1 (0 steps performed)
# /usr/local/lib/python3.7/dist-packages/keras/engine/training_v1.py:2079: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
#     1/10000 [..............................] - ETA: 43:35 - reward: 0.5000
# /usr/local/lib/python3.7/dist-packages/rl/memory.py:37: UserWarning: Not enough entries to sample without replacement. Consider increasing your warm-up phase to avoid oversampling!
#   warnings.warn('Not enough entries to sample without replacement. Consider increasing your warm-up phase to avoid oversampling!')
# 10000/10000 [==============================] - 103s 10ms/step - reward: 0.3927
# 10 episodes - episode_reward: 392.738 [391.052, 393.562] - loss: 0.219 - mae: 13.126 - mean_q: 15.279
#
# Interval 2 (10000 steps performed)
#  1996/10000 [====>.........................] - ETA: 1:20 - reward: 0.3926done, took 123.183 seconds

# %%
#sscores = dqn.test(env_bsl, nb_episodes = 100, visualize = False)
# Out:
# Testing for 100 episodes ...
# Episode 1: reward: 252.078, steps: 1000
# Episode 2: reward: 252.078, steps: 1000
# Episode 3: reward: 252.078, steps: 1000
# Episode 4: reward: 252.078, steps: 1000
# Episode 5: reward: 252.078, steps: 1000
# Episode 6: reward: 252.078, steps: 1000
# Episode 7: reward: 252.078, steps: 1000
# Episode 8: reward: 252.078, steps: 1000
# Episode 9: reward: 252.078, steps: 1000
# Episode 10: reward: 252.078, steps: 1000
# Episode 11: reward: 252.078, steps: 1000
# Episode 12: reward: 252.078, steps: 1000
# Episode 13: reward: 252.078, steps: 1000
# Episode 14: reward: 252.078, steps: 1000
# Episode 15: reward: 252.078, steps: 1000
# Episode 16: reward: 252.078, steps: 1000
# Episode 17: reward: 252.078, steps: 1000
# Episode 18: reward: 252.078, steps: 1000
# Episode 19: reward: 252.078, steps: 1000
# Episode 20: reward: 252.078, steps: 1000
# Episode 21: reward: 252.078, steps: 1000
# Episode 22: reward: 252.078, steps: 1000
# Episode 23: reward: 252.078, steps: 1000
# Episode 24: reward: 252.078, steps: 1000
# Episode 25: reward: 252.078, steps: 1000
# Episode 26: reward: 252.078, steps: 1000
# Episode 27: reward: 252.078, steps: 1000
# Episode 28: reward: 252.078, steps: 1000
# Episode 29: reward: 252.078, steps: 1000
# Episode 30: reward: 252.078, steps: 1000
# Episode 31: reward: 252.078, steps: 1000
# Episode 32: reward: 252.078, steps: 1000
# Episode 33: reward: 252.078, steps: 1000
# Episode 34: reward: 252.078, steps: 1000
# Episode 35: reward: 252.078, steps: 1000
# Episode 36: reward: 252.078, steps: 1000
# Episode 37: reward: 252.078, steps: 1000
# Episode 38: reward: 252.078, steps: 1000
# Episode 39: reward: 252.078, steps: 1000
# Episode 40: reward: 252.078, steps: 1000
# Episode 41: reward: 252.078, steps: 1000
# Episode 42: reward: 252.078, steps: 1000
# Episode 43: reward: 252.078, steps: 1000
# Episode 44: reward: 252.078, steps: 1000
# Episode 45: reward: 252.078, steps: 1000
# Episode 46: reward: 252.078, steps: 1000
# Episode 47: reward: 252.078, steps: 1000
# Episode 48: reward: 252.078, steps: 1000
# Episode 49: reward: 252.078, steps: 1000
# Episode 50: reward: 252.078, steps: 1000
# Episode 51: reward: 252.078, steps: 1000
# Episode 52: reward: 252.078, steps: 1000
# Episode 53: reward: 252.078, steps: 1000
# Episode 54: reward: 252.078, steps: 1000
# Episode 55: reward: 252.078, steps: 1000
# Episode 56: reward: 252.078, steps: 1000
# Episode 57: reward: 252.078, steps: 1000
# Episode 58: reward: 252.078, steps: 1000
# Episode 59: reward: 252.078, steps: 1000
# Episode 60: reward: 252.078, steps: 1000
# Episode 61: reward: 252.078, steps: 1000
# Episode 62: reward: 252.078, steps: 1000
# Episode 63: reward: 252.078, steps: 1000
# Episode 64: reward: 252.078, steps: 1000
# Episode 65: reward: 252.078, steps: 1000
# Episode 66: reward: 252.078, steps: 1000
# Episode 67: reward: 252.078, steps: 1000
# Episode 68: reward: 252.078, steps: 1000
# Episode 69: reward: 252.078, steps: 1000
# Episode 70: reward: 252.078, steps: 1000
# Episode 71: reward: 252.078, steps: 1000
# Episode 72: reward: 252.078, steps: 1000
# Episode 73: reward: 252.078, steps: 1000
# Episode 74: reward: 252.078, steps: 1000
# Episode 75: reward: 252.078, steps: 1000
# Episode 76: reward: 252.078, steps: 1000
# Episode 77: reward: 252.078, steps: 1000
# Episode 78: reward: 252.078, steps: 1000
# Episode 79: reward: 252.078, steps: 1000
# Episode 80: reward: 252.078, steps: 1000
# Episode 81: reward: 252.078, steps: 1000
# Episode 82: reward: 252.078, steps: 1000
# Episode 83: reward: 252.078, steps: 1000
# Episode 84: reward: 252.078, steps: 1000
# Episode 85: reward: 252.078, steps: 1000
# Episode 86: reward: 252.078, steps: 1000
# Episode 87: reward: 252.078, steps: 1000
# Episode 88: reward: 252.078, steps: 1000
# Episode 89: reward: 252.078, steps: 1000
# Episode 90: reward: 252.078, steps: 1000
# Episode 91: reward: 252.078, steps: 1000
# Episode 92: reward: 252.078, steps: 1000
# Episode 93: reward: 252.078, steps: 1000
# Episode 94: reward: 252.078, steps: 1000
# Episode 95: reward: 252.078, steps: 1000
# Episode 96: reward: 252.078, steps: 1000
# Episode 97: reward: 252.078, steps: 1000
# Episode 98: reward: 252.078, steps: 1000
# Episode 99: reward: 252.078, steps: 1000
# Episode 100: reward: 252.078, steps: 1000

# %%
len(Network_energy_drl)
my_array = np.array(Network_energy_drl)
NTE=np.reshape(Network_energy_drl,(12000,8))

# %%
len(Network_energy_baseline)
# Out:
# 12000

# %%
len(power_baseline)
# Out:
# 12000

# %%
manish = np.array(power_baseline)

# %%
pd.DataFrame(manish).to_csv('/content/drive/MyDrive/Colab Notebooks/total_energy_baseline.csv')

# %%
manish = np.array(Network_energy_drl)

# %%
pd.DataFrame(manish).to_csv('/content/drive/MyDrive/Colab Notebooks/Energy_e4.csv')

# %%
print(len(drl))
print(len(baseline))
baseline.append(baseline[-1])
print(len(baseline))
# Out:
# 1000
# 999
# 1000

# %%
print(power_drl)
# Out:
# [4.0, 3.9994539264, 3.9994539264, 3.9989078528, 3.9989078528, 3.9989078528, 3.9989078528, 3.9989078528, 3.9989078528, 3.9989078528, 3.9983617791999997, 3.9978157056, 3.997269632, 3.9967235584000003, 3.9961774848000005, 3.9961774848000005, 3.9956314112000006, 3.9950853376000004, 3.994539264, 3.994539264, 3.9939931904, 3.9934471168, 3.9934471168, 3.9934471168, 3.9929010432000003, 3.9923549696000005, 3.9923549696000005, 3.991808896, 3.9912628224000004, 3.9907167488000006, 3.990170675200001, 3.9896246016000005, 3.9890785280000007, 3.9885324544000005, 3.9879863808000007, 3.9879863808000007, 3.9874403072000004, 3.9868942336000006, 3.986348160000001, 3.985802086400001, 3.985802086400001, 3.985802086400001, 3.985256012800001, 3.9847099392000005, 3.9841638656000007, 3.983617792000001, 3.983071718400001, 3.9825256448000013, 3.9819795712000015, 3.981433497600001, 3.981433497600001, 3.981433497600001, 3.9808874240000014, 3.9803413504000007, 3.9803413504000007, 3.979795276800001, 3.979249203200001, 3.9787031296000013, 3.9781570560000015, 3.9776109824000017, 3.977064908800001, 3.9765188352000007, 3.9759727616000005, 3.9754266880000007, 3.974880614400001, 3.974334540800001, 3.9737884672000012, 3.9732423936000014, 3.9726963200000007, 3.972150246400001, 3.971604172800001, 3.971604172800001, 3.9710580992000013, 3.9705120256000015, 3.9699659520000012, 3.9694198784000014, 3.968873804800001, 3.9683277312000014, 3.9677816576000016, 3.9672355840000013, 3.9666895104000015, 3.9661434368000017, 3.9655973632000014, 3.9650512896000016, 3.964505216000002, 3.963959142400001, 3.9634130688000013, 3.9628669952000015, 3.9623209216000017, 3.961774848000002, 3.961228774400001, 3.9606827008000014, 3.9606827008000014, 3.9601366272000016, 3.959590553600002, 3.9590444800000015, 3.9584984064000017, 3.957952332800002, 3.957406259200002, 3.9568601856000023, 3.956314112000002, 3.955768038400002, 3.955221964800002, 3.954675891200002, 3.954129817600002, 3.954129817600002, 3.954129817600002, 3.953583744000002, 3.953583744000002, 3.953583744000002, 3.953037670400002, 3.9524915968000016, 3.951945523200002, 3.951399449600002, 3.951399449600002, 3.950853376000002, 3.9503073024000024, 3.9497612288000026, 3.9497612288000026, 3.9492151552000028, 3.948669081600003, 3.9481230080000027, 3.947576934400003, 3.947576934400003, 3.9470308608000026, 3.9464847872000024, 3.945938713600002, 3.9453926400000023, 3.9448465664000025, 3.9443004928000027, 3.9443004928000027, 3.943754419200003, 3.943208345600003, 3.9426622720000024, 3.942116198400002, 3.9415701248000024, 3.9410240512000025, 3.9404779776000027, 3.9404779776000027, 3.939931904000003, 3.939385830400003, 3.938839756800003, 3.938293683200003, 3.9377476096000033, 3.9372015360000026, 3.9366554624000027, 3.936109388800003, 3.935563315200003, 3.9350172416000033, 3.9344711680000035, 3.933925094400003, 3.9333790208000026, 3.9328329472000028, 3.932286873600003, 3.9317408000000027, 3.931194726400003, 3.930648652800003, 3.9301025792000033, 3.9295565056000035, 3.929010432000003, 3.9284643584000034, 3.927918284800003, 3.9273722112000033, 3.9268261376000035, 3.9262800640000033, 3.925733990400003, 3.9251879168000032, 3.9246418432000034, 3.9240957696000036, 3.9235496960000034, 3.9230036224000036, 3.9224575488000037, 3.921911475200004, 3.921911475200004, 3.921911475200004, 3.9213654016000037, 3.9213654016000037, 3.920819328000004, 3.920273254400004, 3.9197271808000043, 3.9191811072000045, 3.918635033600004, 3.9180889600000044, 3.917542886400004, 3.916996812800004, 3.916450739200004, 3.9159046656000043, 3.915358592000004, 3.915358592000004, 3.914812518400004, 3.914266444800004, 3.913720371200004, 3.913174297600004, 3.912628224000004, 3.912082150400004, 3.911536076800004, 3.9109900032000042, 3.9104439296000044, 3.909897856000004, 3.9093517824000044, 3.908805708800004, 3.908805708800004, 3.908805708800004, 3.908259635200004, 3.907713561600004, 3.9071674880000042, 3.9066214144000044, 3.906075340800004, 3.9055292672000044, 3.9049831936000046, 3.90443712000 ...

# %%
#Taking every 1000th sample for plotting in DRL.
res = []
i = 0

while(i < 12000):
    res.append(power_drl[i])
    i += 1000
res.append(power_drl[-1])

# %%
print(res)
# Out:
# [4.0, 3.4910594048000236, 2.953722982400049, 2.4180247808000734, 1.87522762240008, 1.33079224320008, 0.816390912000081, 0.6170740480000815, 0.5744803072000819, 0.535163008000082, 0.5013064448000824, 0.4729106176000827, 0.4374158336000828]

# %%
#Taking every 1000th sample for plotting in Baseline.

res1 = []
i = 0

while(i < 12000):
    res1.append(power_baseline[i])
    i += 1000
    
res1.append(power_baseline[-1])
