# %%
from gym import Env
from gym.spaces import Discrete, Box
import numpy as np
import random

# %%
baseline = []  #packets sent in baseline
drl = []       #packets sent in DRL  
power_baseline = []
power_drl = []
Network_energy_drl=[]
Network_energy_baseline=[]

# %%
# import matplotlib.pyplot as plt
# import numpy as np

# X = np.array([i for i in range(1000)])
# y = np.array(baseline_power)
# z = np.array(drl_power)


# plt.plot(X, y, color='r', label='Baseline model')
# plt.plot(X, z, color='g', label='DRL based model')
  
# # Naming the x-axis, y-axis and the whole graph

# plt.xlabel("Episodes")
# plt.ylabel("Power Available")
# plt.title("Battery Drain w.r.to Baseline and DRL")
  
# # Adding legend, which helps us recognize the curve according to it's color
# plt.legend()
# plt.xlim([0, 1200]) 
# plt.ylim([0, 18000]) 
# plt.rcParams["figure.figsize"] = (14,7)
# # To load the display window
# plt.show()

# %%
class Wireless_Env_Baseline(Env):
    def __init__(self):
        
        #Packet Generation Rates calculated from Auto-Regression Model
        self.pgr = [1, 1, 1, 1, 1, 1, 1, 1]
        
        #These are packet queues for each sensor
        self.pulse = []
        self.heart_rate = []
        self.temperature = []
        self.diabetes = []
        self.spo2 = []
        self.ibi = []
        self.eda = []
        self.acc = []
      
        
        #Total initial power
        self.power = 4        
        
        
        #Step count for each episode. It can be changed as per requirement.
        self.count = 1000
        
        #self.sensors = {0 : "Pulse", 1 : "Heart Rate", 2 : "Temprature", 3 : "Diabetes",  : "SpO2", 5 : "EDA", 6 : "IBI", 7 : "ACC"}
                
        # Actions we can take ---> we can select any of 8 sensors for packet transmission.
        self.action_space = Discrete(8)
        
        
        #initial timestamp (Optional---> I have used it for testing purpose.)
        self.time_stamp = 1
        
        #Set the network length(Will update the battery power,,, We can update here the minimum battery sensor)
        self.life = 1000        
        
        #Initial number of packets in queues
        self.state = 0        
        
        
        #This is observation space..will take any random value( Just for model shake...No use in our case.)
        self.observation_space = Box(low=np.array([0]), high=np.array([100]))
    
    
    #calculating reward based on our reward function.
    def get_reward(self, packet_gen_prob, self_queue, others_queue):
        #print("In Reward")
        reward_ = ((len(self_queue) * packet_gen_prob) + 1) / (others_queue - len(self_queue) + 1) + .25
        #reward_ = len(self_queue)*packet_gen_prob
        return reward_
     
        
    #This is crucial function. It defines how the state is changing after each selection. Every update is happening here.    
    def state_change(self): 
        
       
        
        #In baseline...adding 1 packet into each sensor queue as each sensor is sensing 1 packet per step.
        self.ibi.append(1)
        self.eda.append(1)        
        self.diabetes.append(1)        
        self.heart_rate.append(1)
        self.acc.append(1)       
        self.temperature.append(1)        
        self.pulse.append(1)       
        self.spo2.append(1)
            
        
    
    def step(self, action):       
        
        #for testing.
        self.count -= 1
        
        #Power equation used here. Can be changed as per requirement.
        self.power -= (16.31 * 10e-9 * 256 + 1.97 * 10e-9 * 100 * 256)
        
        #Testing
        #print("Selected sensor is --> ", action)
        
        #Changing the state.
        self.state_change()
        
        total_pending_packets = len(self.pulse) + len(self.heart_rate) + len(self.temperature) + len(self.diabetes) + len(self.spo2) + len(self.ibi) + len(self.eda) + len(self.acc) 
        
        #print("total pending packets -----> ", total_pending_packets)
        
        
        #In this if else ladder, we are updating based on selected node.
        
        if(self.count > 0):
            baseline.append(total_pending_packets)
#             drl.append(len(self.pulse) + len(self.heart_rate) + len(self.temperature) + len(self.diabetes))
        
        if(self.power > 0):
            power_baseline.append(self.power)
        if(self.power <= 0):
            power_baseline.append(0)
        Network_energy_baseline.append(self.power)
        if action == 0:
            #print(" Sensor Queue size is ", len(self.pulse))
            if(len(self.pulse) == 0):
                reward = 0
            else:
                
                reward = self.get_reward(self.pgr[0], self.pulse, total_pending_packets)
                if(len(self.pulse) != 0):
                    self.pulse.pop()
        
        elif action == 1:
            #print(" Sensor Queue size is ", len(self.heart_rate))
            if(len(self.heart_rate) == 0):
                reward = 0
            else:
                
                reward = self.get_reward(self.pgr[1], self.heart_rate, total_pending_packets)
                if len(self.heart_rate) != 0:
                    self.heart_rate.pop()
        
        elif action == 2:
            #print(" Sensor Queue size is ", len(self.temperature))
            if len(self.temperature) == 0:
                reward = 0
            else:
                
                reward = self.get_reward(self.pgr[2], self.temperature, total_pending_packets)        
                if len(self.temperature) != 0:
                    self.temperature.pop()
            
        elif action == 3:
            #print(" Sensor Queue size is ", len(self.diabetes ) )
            if(len(self.diabetes) == 0):
                reward = 0
            else:
                
                reward = self.get_reward(self.pgr[3], self.diabetes, total_pending_packets)
                if len(self.diabetes) != 0:
                    self.diabetes.pop()
        
        elif action == 4:
            #print(" Sensor Queue size is ", len(self.spo2))
            if(len(self.spo2) == 0):
                reward = 0
            else:
                
                reward = self.get_reward(self.pgr[4], self.spo2, total_pending_packets)        
                if len(self.spo2) != 0:
                    self.spo2.pop()
        elif action == 5:
            #print(" Sensor Queue size is ",len(self.eda))
            if(len(self.eda) == 0):
                reward = 0
            else:
                
                reward = self.get_reward(self.pgr[5], self.eda, total_pending_packets)        
                if len(self.eda) != 0:
                    self.eda.pop()
        elif action == 6:
            #print(" Sensor Queue size is ", len(self.ibi))
            if(len(self.ibi) == 0):
                reward = 0
            else:
                
                reward = self.get_reward(self.pgr[6], self.ibi, total_pending_packets)        
                if len(self.ibi) != 0:
                    self.ibi.pop()
        else:
            #print(" Sensor Queue size is ",len(self.acc))
            if(len(self.acc) == 0):
                reward = 0
            else:
                
                reward = self.get_reward(self.pgr[7], self.acc, total_pending_packets)        
                if len(self.acc) != 0:
                    self.acc.pop()  
        
        
        #Reducing life by 1, here we can also use battery power. 
        self.life -= 1    
        
       
        
        if self.life <= 0: 
            done = True
        else:
            done = False   
        
        # Apply temperature noise
        #self.state += random.randint(-1,1)
        
        # Set placeholder for info
        info = {}
        
        # Return step information
        return self.state, reward, done, info

    def render(self):
        #For Visualization Purpose
        pass
    
    def reset(self):
        # Reset shower temperature
        self.state = 0
        # Reset shower time
        self.life = 1000
        
        #Reset all packet queues
        self.pulse = []
        self.heart_rate = []
        self.temperature = []
        self.diabetes = []
        self.spo2 = []
        self.ibi = []
        self.eda = []
        self.acc = []
        
        return self.state

# %%
#Here also, all parameters are same as Baseline Model apart from PGR.
class Wireless_Env_DRL(Env):
    def __init__(self):
        
        #Packet Generation Rates calculated from Auto-Regression Model
        #self.pgr = [0.09, 0.525, 0.313, 0.879, 0.03, 0.961, 0.978, 0.374]
        self.pgr = [11,2,3,1,30,1,1,2]
        self.pulse = []
        self.heart_rate = []
        self.temperature = []
        self.diabetes = []
        self.spo2 = []
        self.ibi = []
        self.eda = []
        self.acc = []
        
        self.power = [.5, .5, .5, .5, .5, .5, .5, .5]
        self.count = 1001
        #self.flag = 1
        #self.sensors = {0 : "Pulse", 1 : "Heart Rate", 2 : "Temprature", 3 : "Diabetes",  : "SpO2", 5 : "EDA", 6 : "IBI", 7 : "ACC"}
                
        # Actions we can take, down, stay, up
        self.action_space = Discrete(8)
        
        self.time_stamp = 1
        
        #Set the network length(Will update the battery power,,, We can update here the minimum battery sensor)
        self.life = 1000        
        
        #Initial number of packets in queues
        self.state = 0        
        
        self.observation_space = Box(low=np.array([0]), high=np.array([100]))
        
    def get_reward(self, packet_gen_prob, self_queue, others_queue):
        #print("In Reward")
        reward_ = (((len(self_queue) * packet_gen_prob) + 1) / (others_queue - len(self_queue) + 1) + .25)
        #reward_ = len(self_queue)*packet_gen_prob
        return reward_
        
    def state_change(self): 
        
        ts = self.time_stamp
        
        self.time_stamp += 1
        
        self.ibi.append(1)
        self.eda.append(1)        
        self.diabetes.append(1)        
        
        if ts % 2 == 0:
            self.heart_rate.append(1)
        
        if ts % 2 == 0:
            self.acc.append(1)
        
        if ts % 3 == 0:
            self.temperature.append(1)
            
        if ts % 11 == 0:
            self.pulse.append(1)            
            
        if ts % 30 == 0:
            self.spo2.append(1)
            
        
    
    def step(self, action):       
        
        self.count -= 1
        
        #Power function. But we will reduce power only when sensor is selected.
        p = (16.31 * 10e-9 * 256 + 1.97 * 10e-9 * 100 * 256)
        
        
        #print("Selected sensor is --> ", action)
        
        self.state_change()
        
        total_pending_packets = len(self.pulse) + len(self.heart_rate) + len(self.temperature) + len(self.diabetes) + len(self.spo2) + len(self.ibi) + len(self.eda) + len(self.acc) 
        
        #print("total pending packets -----> ", total_pending_packets)
        
        if(self.count > 0):
            
            drl.append(total_pending_packets)
            
        if(sum(self.power) > 0):
            power_drl.append(sum(self.power))
        
        Network_energy_drl.extend(self.power)
        if action == 0:
            #print(" Sensor Queue size is ", len(self.pulse))
            if(len(self.pulse) == 0):
                reward = 0
            else:
                if(self.power[0] - p > 0): #here I am reducing power if this sensor is selected. same for others as well.
                    self.power[0] -= p
                    #print(power)
                reward = self.get_reward(self.pgr[0], self.pulse, total_pending_packets)
                if(len(self.pulse) != 0):
                    self.pulse.pop()
        
        elif action == 1:
            #print(" Sensor Queue size is ", len(self.heart_rate))
            if(len(self.heart_rate) == 0):
                reward = 0
            else:
                if(self.power[1] - p > 0):
                    self.power[1] -= p
                reward = self.get_reward(self.pgr[1], self.heart_rate, total_pending_packets)
                if len(self.heart_rate) != 0:
                    self.heart_rate.pop()
        
        elif action == 2:
            #print(" Sensor Queue size is ", len(self.temperature))
            if len(self.temperature) == 0:
                reward = 0
            else:
                if(self.power[2] - p > 0):
                    self.power[2] -= p
                reward = self.get_reward(self.pgr[2], self.temperature, total_pending_packets)        
                if len(self.temperature) != 0:
                    self.temperature.pop()
            
        elif action == 3:
            #print(" Sensor Queue size is ", len(self.diabetes ) )
            if(len(self.diabetes) == 0):
                reward = 0
            else:
                if(self.power[3] - p > 0):
                    self.power[3] -= p
                reward = self.get_reward(self.pgr[3], self.diabetes, total_pending_packets)
                if len(self.diabetes) != 0:
                    self.diabetes.pop()
        
        elif action == 4:
            #print(" Sensor Queue size is ", len(self.spo2))
            if(len(self.spo2) == 0):
                reward = 0
            else:
                if(self.power[4] - p > 0):
                    self.power[4] -= p
                reward = self.get_reward(self.pgr[4], self.spo2, total_pending_packets)        
                if len(self.spo2) != 0:
                    self.spo2.pop()
        elif action == 5:
            #print(" Sensor Queue size is ",len(self.eda))
            if(len(self.eda) == 0):
                reward = 0
            else:
                if(self.power[5] - p > 0):
                    self.power[5] -= p
                reward = self.get_reward(self.pgr[5], self.eda, total_pending_packets)        
                if len(self.eda) != 0:
                    self.eda.pop()
        elif action == 6:
            #print(" Sensor Queue size is ", len(self.ibi))
            if(len(self.ibi) == 0):
                reward = 0
            else:
                if(self.power[6] - p > 0):
                    self.power[6] -= p
                reward = self.get_reward(self.pgr[6], self.ibi, total_pending_packets)        
                if len(self.ibi) != 0:
                    self.ibi.pop()
        else:
            #print(" Sensor Queue size is ",len(self.acc))
            if(len(self.acc) == 0):
                reward = 0
            else:
                if(self.power[7] - p > 0):
                    self.power[7] -= p
                reward = self.get_reward(self.pgr[7], self.acc, total_pending_packets)        
                if len(self.acc) != 0:
                    self.acc.pop()  
        
        
        
        self.life -= 1    
            
        if self.life <= 0: 
            done = True
        else:
            done = False   
        
        # Apply temperature noise
        #self.state += random.randint(-1,1)
        
        # Set placeholder for info
        info = {}
        
        # Return step information
        return self.state, reward, done, info

    def render(self):
        #For Visualization Purpose
        pass
    
    #This step resets the parameters after each 1000 steps. For training purpose. can be updated for battery life as well.
    def reset(self):
        # Reset shower temperature
        self.state = 0
        # Reset shower time
        self.life = 1000
        
        #Reset all packet queues
        self.pulse = []
        self.heart_rate = []
        self.temperature = []
        self.diabetes = []
        self.spo2 = []
        self.ibi = []
        self.eda = []
        self.acc = []
        
        return self.state

# %%
env_drl = Wireless_Env_DRL()
# Out:
# /usr/local/lib/python3.7/dist-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %%
env_bsl = Wireless_Env_Baseline()
# Out:
# /usr/local/lib/python3.7/dist-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %%
env_bsl.observation_space.sample()
# Out:
# array([16.176758], dtype=float32)

# %%
env_drl.observation_space.sample()
# Out:
# array([58.830322], dtype=float32)

# %%
 episodes = 10
 sco_drl=[]

 for episode in range(1, episodes+1):
     state = env_drl.reset()
     done = False
     score = 0 
    
     while not done:
         #env.render()
         action = env_drl.action_space.sample()
         n_state, reward, done, info = env_drl.step(action)
         score+=reward
     print('Episode:{} Reward:{}'.format(episode, score))
     sco_drl.append(score)
# Out:
# Episode:1 Reward:417.25362525303314
# Episode:2 Reward:429.5295343861384
# Episode:3 Reward:430.6308458155566
# Episode:4 Reward:423.6848805115196
# Episode:5 Reward:434.4335785240289
# Episode:6 Reward:429.23397656795987
# Episode:7 Reward:427.5875358080102
# Episode:8 Reward:424.56318555434973
# Episode:9 Reward:425.7799436417486
# Episode:10 Reward:426.08429037777165

# %%
sco_drl
# Out:
# [417.25362525303314,
#  429.5295343861384,
#  430.6308458155566,
#  423.6848805115196,
#  434.4335785240289,
#  429.23397656795987,
#  427.5875358080102,
#  424.56318555434973,
#  425.7799436417486,
#  426.08429037777165]

# %%
 episodes = 10
 sco_bsl=[]
 for episode in range(1, episodes+1):
     state = env_bsl.reset()
     done = False
     score = 0 
    
     while not done:
         #env.render()
         action = env_bsl.action_space.sample()
         n_state, reward, done, info = env_bsl.step(action)
         score+=reward
     print('Episode:{} Reward:{}'.format(episode, score))
     sco_bsl.append(score)
# Out:
# Episode:1 Reward:394.0257528129909
# Episode:2 Reward:393.901450419518
# Episode:3 Reward:393.8623443691321
# Episode:4 Reward:393.73259191266084
# Episode:5 Reward:394.0173895379131
# Episode:6 Reward:393.7064810618956
# Episode:7 Reward:393.7808653721741
# Episode:8 Reward:393.6681182552839
# Episode:9 Reward:393.82970377474896
# Episode:10 Reward:393.6862913946571

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
A = np.array(sco_drl)

# %%
pd.DataFrame(A).to_csv('/content/drive/MyDrive/Colab Notebooks/reward_drl_e1.csv')

# %%
B = np.array(sco_bsl)

# %%
pd.DataFrame(B).to_csv('/content/drive/MyDrive/Colab Notebooks/reward_bsl_e1.csv')

# %%
import numpy as np
import tensorflow
import keras
from keras.models import Sequential
from keras.layers import Dense, Flatten
from tensorflow.keras.optimizers import Adam
model = keras.Sequential()

# %%
states = env_bsl.observation_space.shape
actions = env_bsl.action_space.n

# %%
states = env_drl.observation_space.shape
actions = env_drl.action_space.n

# %%
env_drl.action_space
# Out:
# Discrete(8)

# %%
env_bsl.observation_space
# Out:
# Box(0.0, 100.0, (1,), float32)

# %%
actions
# Out:
# 8

# %%
del model

# %%
def build_model(states, actions):
    model = keras.Sequential()
    
    model.add(Dense(32, activation='relu', input_shape=states))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(actions, activation='linear'))
    return model

# %%
model = build_model(states, actions)

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 32)                64
#
#  dense_4 (Dense)             (None, 64)                2112
#
#  dense_5 (Dense)             (None, 8)                 520
#
# =================================================================
# Total params: 2,696
# Trainable params: 2,696
# Non-trainable params: 0
# _________________________________________________________________

# %%
# !pip install keras-rl2
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: keras-rl2 in /usr/local/lib/python3.7/dist-packages (1.0.5)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.7/dist-packages (from keras-rl2) (2.8.2+zzzcolab20220527125636)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-rl2) (1.14.1)
# Requirement already satisfied: tensorflow-estimator<2.9,>=2.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-rl2) (2.8.0)
# Requirement already satisfied: gast>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-rl2) (0.5.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-rl2) (3.3.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-rl2) (1.1.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-rl2) (3.1.0)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-rl2) (1.21.6)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-rl2) (4.1.1)
# Requirement already satisfied: flatbuffers>=1.12 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-rl2) (2.0)
# Requirement already satisfied: keras<2.9,>=2.8.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-rl2) (2.8.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-rl2) (1.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-rl2) (57.4.0)
# Requirement already satisfied: absl-py>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-rl2) (1.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-rl2) (1.6.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-rl2) (1.46.3)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-rl2) (0.26.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-rl2) (1.1.2)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-rl2) (3.17.3)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-rl2) (0.2.0)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-rl2) (2.8.0)
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-rl2) (14.0.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from astunparse>=1.6.0->tensorflow->keras-rl2) (0.37.1)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py>=2.9.0->tensorflow->keras-rl2) (1.5.2)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow->keras-rl2) (2.23.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow->keras-rl2) (1.35.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow->keras-rl2) (0.6.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow->keras-rl2) (3.3.7)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow->keras-rl2) (1.8.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow->keras-rl2) (0.4.6)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow->keras-rl2) (1.0.1)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow->keras-rl2) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow->keras-rl2) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow->keras-rl2) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow->keras-rl2) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow->keras-rl2) (4.11.4)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow->keras-rl2) (3.8.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow->keras-rl2) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow->keras-rl2) (2022.6.15)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow->keras-rl2) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow->keras-rl2) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow->keras-rl2) (1.24.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow->keras-rl2) (3.2.0)

# %%
from rl.agents import DQNAgent
from rl.policy import BoltzmannQPolicy
from rl.memory import SequentialMemory

# %%
def build_agent(model, actions):
    policy = BoltzmannQPolicy()
    memory = SequentialMemory(limit=12000, window_length=1)
    dqn = DQNAgent(model=model, memory=memory, policy=policy, 
                  nb_actions=actions, nb_steps_warmup=10, target_model_update=1e-2)
    return dqn

# %%
#Run DRL based model
dqn = build_agent(model, actions)
dqn.compile(Adam(lr=1e-3), metrics=['mae'])
dqn.fit(env_drl, nb_steps=12000, visualize=False, verbose=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Training for 12000 steps ...
# Interval 1 (0 steps performed)
#     1/10000 [..............................] - ETA: 13:04 - reward: 0.9167
# /usr/local/lib/python3.7/dist-packages/keras/engine/training_v1.py:2079: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# /usr/local/lib/python3.7/dist-packages/rl/memory.py:37: UserWarning: Not enough entries to sample without replacement. Consider increasing your warm-up phase to avoid oversampling!
#   warnings.warn('Not enough entries to sample without replacement. Consider increasing your warm-up phase to avoid oversampling!')
# 10000/10000 [==============================] - 96s 10ms/step - reward: 0.4324
# 10 episodes - episode_reward: 432.439 [419.713, 446.458] - loss: 0.107 - mae: 3.948 - mean_q: 4.567
#
# Interval 2 (10000 steps performed)
#  1995/10000 [====>.........................] - ETA: 1:10 - reward: 0.4430done, took 113.346 seconds

# %%
sscores = dqn.test(env_drl, nb_episodes = 300, visualize = False)
# Out:
# Testing for 300 episodes ...
# Episode 1: reward: 127.522, steps: 1000
# Episode 2: reward: 127.440, steps: 1000
# Episode 3: reward: 127.503, steps: 1000
# Episode 4: reward: 127.496, steps: 1000
# Episode 5: reward: 127.477, steps: 1000
# Episode 6: reward: 127.558, steps: 1000
# Episode 7: reward: 127.510, steps: 1000
# Episode 8: reward: 127.494, steps: 1000
# Episode 9: reward: 127.566, steps: 1000
# Episode 10: reward: 127.519, steps: 1000
# Episode 11: reward: 127.498, steps: 1000
# Episode 12: reward: 127.572, steps: 1000
# Episode 13: reward: 127.460, steps: 1000
# Episode 14: reward: 127.442, steps: 1000
# Episode 15: reward: 127.545, steps: 1000
# Episode 16: reward: 127.497, steps: 1000
# Episode 17: reward: 127.487, steps: 1000
# Episode 18: reward: 127.559, steps: 1000
# Episode 19: reward: 127.515, steps: 1000
# Episode 20: reward: 127.494, steps: 1000
# Episode 21: reward: 127.569, steps: 1000
# Episode 22: reward: 127.520, steps: 1000
# Episode 23: reward: 127.500, steps: 1000
# Episode 24: reward: 127.502, steps: 1000
# Episode 25: reward: 127.462, steps: 1000
# Episode 26: reward: 127.476, steps: 1000
# Episode 27: reward: 127.547, steps: 1000
# Episode 28: reward: 127.509, steps: 1000
# Episode 29: reward: 127.488, steps: 1000
# Episode 30: reward: 127.565, steps: 1000
# Episode 31: reward: 127.516, steps: 1000
# Episode 32: reward: 127.498, steps: 1000
# Episode 33: reward: 127.570, steps: 1000
# Episode 34: reward: 127.522, steps: 1000
# Episode 35: reward: 127.440, steps: 1000
# Episode 36: reward: 127.503, steps: 1000
# Episode 37: reward: 127.496, steps: 1000
# Episode 38: reward: 127.477, steps: 1000
# Episode 39: reward: 127.558, steps: 1000
# Episode 40: reward: 127.510, steps: 1000
# Episode 41: reward: 127.494, steps: 1000
# Episode 42: reward: 127.566, steps: 1000
# Episode 43: reward: 127.519, steps: 1000
# Episode 44: reward: 127.498, steps: 1000
# Episode 45: reward: 127.572, steps: 1000
# Episode 46: reward: 127.460, steps: 1000
# Episode 47: reward: 127.442, steps: 1000
# Episode 48: reward: 127.545, steps: 1000
# Episode 49: reward: 127.497, steps: 1000
# Episode 50: reward: 127.487, steps: 1000
# Episode 51: reward: 127.559, steps: 1000
# Episode 52: reward: 127.515, steps: 1000
# Episode 53: reward: 127.494, steps: 1000
# Episode 54: reward: 127.569, steps: 1000
# Episode 55: reward: 127.520, steps: 1000
# Episode 56: reward: 127.500, steps: 1000
# Episode 57: reward: 127.502, steps: 1000
# Episode 58: reward: 127.462, steps: 1000
# Episode 59: reward: 127.476, steps: 1000
# Episode 60: reward: 127.547, steps: 1000
# Episode 61: reward: 127.509, steps: 1000
# Episode 62: reward: 127.488, steps: 1000
# Episode 63: reward: 127.565, steps: 1000
# Episode 64: reward: 127.516, steps: 1000
# Episode 65: reward: 127.498, steps: 1000
# Episode 66: reward: 127.570, steps: 1000
# Episode 67: reward: 127.522, steps: 1000
# Episode 68: reward: 127.440, steps: 1000
# Episode 69: reward: 127.503, steps: 1000
# Episode 70: reward: 127.496, steps: 1000
# Episode 71: reward: 127.477, steps: 1000
# Episode 72: reward: 127.558, steps: 1000
# Episode 73: reward: 127.510, steps: 1000
# Episode 74: reward: 127.494, steps: 1000
# Episode 75: reward: 127.566, steps: 1000
# Episode 76: reward: 127.519, steps: 1000
# Episode 77: reward: 127.498, steps: 1000
# Episode 78: reward: 127.572, steps: 1000
# Episode 79: reward: 127.460, steps: 1000
# Episode 80: reward: 127.442, steps: 1000
# Episode 81: reward: 127.545, steps: 1000
# Episode 82: reward: 127.497, steps: 1000
# Episode 83: reward: 127.487, steps: 1000
# Episode 84: reward: 127.559, steps: 1000
# Episode 85: reward: 127.515, steps: 1000
# Episode 86: reward: 127.494, steps: 1000
# Episode 87: reward: 127.569, steps: 1000
# Episode 88: reward: 127.520, steps: 1000
# Episode 89: reward: 127.500, steps: 1000
# Episode 90: reward: 127.502, steps: 1000
# Episode 91: reward: 127.462, steps: 1000
# Episode 92: reward: 127.476, steps: 1000
# Episode 93: reward: 127.547, steps: 1000
# Episode 94: reward: 127.509, steps: 1000
# Episode 95: reward: 127.488, steps: 1000
# Episode 96: reward: 127.565, steps: 1000
# Episode 97: reward: 127.516, steps: 1000
# Episode 98: reward: 127.498, steps: 1000
# Episode 99: reward: 127.570, steps: 1000
# Episode 100: reward: 127.522, steps: 1000
# Episode 101: reward: 127.440, steps: 1000
# Episode 102: reward: 127.503, steps: 1000
# Episode 103: reward: 127.496, steps: 1000
# Episode 104: reward: 127.477, steps: 1000
# Episode 105: reward: 127.558, steps: 1000
# Episode 106: reward: 127.510, steps: 1000
# Episode 107: reward: 127.494, steps: 1000
# Episode 108: reward: 127.566, steps: 1000
# Episode 109: reward: 127.519, steps: 1000
# Episode 110: reward: 127.498, steps: 1000
# Episode 111: reward: 127.572, steps: 1000
# Episode 112: reward: 127.460, steps: 1000
# Episode 113: reward: 127.442, steps: 1000
# Episode 114: reward: 127.545, steps: 1000
# Episode 115: reward: 127.497, steps: 1000
# Episode 116: reward: 127.487, steps: 1000
# Episode 117: reward: 127.559, steps: 1000
# Episode 118: reward: 127.515, steps: 1000
# Episode 119: reward: 127.494, steps: 1000
# Episode 120: reward: 127.569, steps: 1000
# Episode 121: reward: 127.520, steps: 1000
# Episode 122: reward: 127.500, steps: 1000
# Episode 123: reward: 127.502, steps: 1000
# Episode 124: reward: 127.462, steps: 1000
# Episode 125: reward: 127.476, steps: 1000
# Episode 126: reward: 127.547, steps: 1000
# Episode 127: reward: 127.509, steps: 1000
# Episode 128: reward: 127.488, steps: 1000
# Episode 129: reward: 127.565, steps: 1000
# Episode 130: reward: 127.516, steps: 1000
# Episode 131: reward: 127.498, steps: 1000
# Episode 132: reward: 127.570, steps: 1000
# Episode 133: reward: 127.522, steps: 1000
# Episode 134: reward: 127.440, steps: 1000
# Episode 135: reward: 127.503, steps: 1000
# Episode 136: reward: 127.496, steps: 1000
# Episode 137: reward: 127.477, steps: 1000
# Episode 138: reward: 127.558, steps: 1000
# Episode 139: reward: 127.510, steps: 1000
# Episode 140: reward: 127.494, steps: 1000
# Episode 141: reward: 127.566, steps: 1000
# Episode 142: reward: 127.519, steps: 1000
# Episode 143: reward: 127.498, steps: 1000
# Episode 144: reward: 127.572, steps: 1000
# Episode 145: reward: 127.460, steps: 1000
# Episode 146: reward: 127.442, steps: 1000
# Episode 147: reward: 127.545, steps: 1000
# Episode 148: reward: 127.497, steps: 1000
# Episode 149: reward: 127.487, steps: 1000
# Episode 150: reward: 127.559, steps: 1000
# Episode 151: reward: 127.515, steps: 1000
# Episode 152: reward: 127.494, steps: 1000
# Episode 153: reward: 127.569, steps: 1000
# Episode 154: reward: 127.520, steps: 1000
# Episode 155: reward: 127.500, steps: 1000
# Episode 156: reward: 127.502, steps: 1000
# Episode 157: reward: 127.462, steps: 1000
# Episode 158: reward: 127.476, steps: 1000
# Episode 159: reward: 127.547, steps: 1000
# Episode 160: reward: 127.509, steps: 1000
# Episode 161: reward: 127.488, steps: 1000
# Episode 162: reward: 127.565, steps: 1000
# Episode 163: reward: 127.516, steps: 1000
# Episode 164: reward: 127.498, steps: 1000
# Episode 165: reward: 127.570, steps: 1000
# Episode 166: reward: 127.522, steps: 1000
# Episode 167: reward: 127.440, steps: 1000
# Episode 168: reward: 127.503, steps: 1000
# Episode 169: reward: 127.496, steps: 1000
# Episode 170: reward: 127.477, steps: 1000
# Episode 171: reward: 127.558, steps: 1000
# Episode 172: reward: 127.510, steps: 1000
# Episode 173: reward: 127.494, steps: 1000
# Episode 174: reward: 127.566, steps: 1000
# Episode 175: reward: 127.519, steps: 1000
# Episode 176: reward: 127.498, steps: 1000
# Episode 177: reward: 127.572, steps: 1000
# Episode 178: reward: 127.460, steps: 1000
# Episode 179: reward: 127.442, steps: 1000
# Episode 180: reward: 127.545, steps: 1000
# Episode 181: reward: 127.497, steps: 1000
# Episode 182: reward: 127.487, steps: 1000
# Episode 183: reward: 127.559, steps: 1000
# Episode 184: reward: 127.515, steps: 1000
# Episode 185: reward: 127.494, steps: 1000
# Episode 186: reward: 127.569, steps: 1000
# Episode 187: reward: 127.520, steps: 1000
# Episode 188: reward: 127.500, steps: 1000
# Episode 189: reward: 127.502, steps: 1000
# Episode 190: reward: 127.462, steps: 1000
# Episode 191: reward: 127.476, steps: 1000
# Episode 192: reward: 127.547, steps: 1000
# Episode 193: reward: 127.509, steps: 1000
# Episode 194: reward: 127.488, steps: 1000
# Episode 195: reward: 127.565, steps: 1000
# Episode 196: reward: 127.516, steps: 1000
# Episode 197: reward: 127.498, steps: 1000
# Episode 198: reward: 127.570, steps: 1000
# Episode 199: reward: 127.522, steps: 1000
# Episode 200: reward: 127.440, steps: 1000
# Episode 201: reward: 127.503, steps: 1000
# Episode 202: reward: 127.496, steps: 1000
# Episode 203: reward: 127.477, steps: 1000
# Episode 204: reward: 127.558, steps: 1000
# Episode 205: reward: 127.510, steps: 1000
# Episode 206: reward: 127.494, steps: 1000
# Episode 207: reward: 127.566, steps: 1000
# Episode 208: reward: 127.519, steps: 1000
# Episode 209: reward: 127.498, steps: 1000
# Episode 210: reward: 127.572, steps: 1000
# Episode 211: reward: 127.460, steps: 1000
# Episode 212: reward: 127.442, steps: 1000
# Episode 213: reward: 127.545, steps: 1000
# Episode 214: reward: 127.497, steps: 1000
# Episode 215: reward: 127.487, steps: 1000
# Episode 216: reward: 127.559, steps: 1000
# Episode 217: reward: 127.515, steps: 1000
# Episode 218: reward: 127.494, steps: 1000
# Episode 219: reward: 127.569, steps: 1000
# Episode 220: reward: 127.520, steps: 1000
# Episode 221: reward: 127.500, steps: 1000
# Episode 222: reward: 127.502, steps: 1000
# Episode 223: reward: 127.462, steps: 1000
# Episode 224: reward: 127.476, steps: 1000
# Episode 225: reward: 127.547, steps: 1000
# Episode 226: reward: 127.509, steps: 1000
# Episode 227: reward: 127.488, steps: 1000
# Episode 228: reward: 127.565, steps: 1000
# Episode 229: reward: 127.516, steps: 1000
# Episode 230: reward: 127.498, steps: 1000
# Episode 231: reward: 127.570, steps: 1000
# Episode 232: reward: 127.522, steps: 1000
# Episode 233: reward: 127.440, steps: 1000
# Episode 234: reward: 127.503, steps: 1000
# Episode 235: reward: 127.496, steps: 1000
# Episode 236: reward: 127.477, steps: 1000
# Episode 237: reward: 127.558, steps: 1000
# Episode 238: reward: 127.510, steps: 1000
# Episode 239: reward: 127.494, steps: 1000
# Episode 240: reward: 127.566, steps: 1000
# Episode 241: reward: 127.519, steps: 1000
# Episode 242: reward: 127.498, steps: 1000
# Episode 243: reward: 127.572, steps: 1000
# Episode 244: reward: 127.460, steps: 1000
# Episode 245: reward: 127.442, steps: 1000
# Episode 246: reward: 127.545, steps: 1000
# Episode 247: reward: 127.497, steps: 1000
# Episode 248: reward: 127.487, steps: 1000
# Episode 249: reward: 127.559, steps: 1000
# Episode 250: reward: 127.515, steps: 1000
# Episode 251: reward: 127.494, steps: 1000
# Episode 252: reward: 127.569, steps: 1000
# Episode 253: reward: 127.520, steps: 1000
# Episode 254: reward: 127.500, steps: 1000
# Episode 255: reward: 127.502, steps: 1000
# Episode 256: reward: 127.462, steps: 1000
# Episode 257: reward: 127.476, steps: 1000
# Episode 258: reward: 127.547, steps: 1000
# Episode 259: reward: 127.509, steps: 1000
# Episode 260: reward: 127.488, steps: 1000
# Episode 261: reward: 127.565, steps: 1000
# Episode 262: reward: 127.516, steps: 1000
# Episode 263: reward: 127.498, steps: 1000
# Episode 264: reward: 127.570, steps: 1000
# Episode 265: reward: 127.522, steps: 1000
# Episode 266: reward: 127.440, steps: 1000
# Episode 267: reward: 127.503, steps: 1000
# Episode 268: reward: 127.496, steps: 1000
# Episode 269: reward: 127.477, steps: 1000
# Episode 270: reward: 127.558, steps: 1000
# Episode 271: reward: 127.510, steps: 1000
# Episode 272: reward: 127.494, steps: 1000
# Episode 273: reward: 127.566, steps: 1000
# Episode 274: reward: 127.519, steps: 1000
# Episode 275: reward: 127.498, steps: 1000
# Episode 276: reward: 127.572, steps: 1000
# Episode 277: reward: 127.460, steps: 1000
# Episode 278: reward: 127.442, steps: 1000
# Episode 279: reward: 127.545, steps: 1000
# Episode 280: reward: 127.497, steps: 1000
# Episode 281: reward: 127.487, steps: 1000
# Episode 282: reward: 127.559, steps: 1000
# Episode 283: reward: 127.515, steps: 1000
# Episode 284: reward: 127.494, steps: 1000
# Episode 285: reward: 127.569, steps: 1000
# Episode 286: reward: 127.520, steps: 1000
# Episode 287: reward: 127.500, steps: 1000
# Episode 288: reward: 127.502, steps: 1000
# Episode 289: reward: 127.462, steps: 1000
# Episode 290: reward: 127.476, steps: 1000
# Episode 291: reward: 127.547, steps: 1000
# Episode 292: reward: 127.509, steps: 1000
# Episode 293: reward: 127.488, steps: 1000
# Episode 294: reward: 127.565, steps: 1000
# Episode 295: reward: 127.516, steps: 1000
# Episode 296: reward: 127.498, steps: 1000
# Episode 297: reward: 127.570, steps: 1000
# Episode 298: reward: 127.522, steps: 1000
# Episode 299: reward: 127.440, steps: 1000
# Episode 300: reward: 127.503, steps: 1000

# %%
#sscores.formate
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-43-20947a6a400e> in <module>()
# ----> 1 sscores.formate
#
# AttributeError: 'History' object has no attribute 'formate'

# %%
#len(sscores)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-5c26fff09b06> in <module>()
# ----> 1 len(sscores)
#
# TypeError: object of type 'History' has no len()

# %%
#print(sscores)
# Out:
# <keras.callbacks.History object at 0x7f6e620b2850>

# %%
len(Network_energy_drl)
# Out:
# 3296000

# %%
my_array = np.array(Network_energy_drl)

# %%
NTE=np.reshape(Network_energy_drl,(12000,8))

# %%
import pandas as pd

# %%
df=pd.DataFrame(NTE)

# %%
df
# Out:
#               0         1         2         3         4         5         6  \
# 0      0.500000  0.500000  0.500000  0.500000  0.500000  0.500000  0.500000
# 1      0.500000  0.500000  0.500000  0.500000  0.500000  0.500000  0.500000
# 2      0.500000  0.500000  0.500000  0.500000  0.500000  0.500000  0.500000
# 3      0.500000  0.499454  0.500000  0.500000  0.500000  0.500000  0.500000
# 4      0.500000  0.499454  0.500000  0.500000  0.500000  0.500000  0.500000
# ...         ...       ...       ...       ...       ...       ...       ...
# 11995  0.000343  0.000343  0.000343  0.000343  0.284847  0.000343  0.000343
# 11996  0.000343  0.000343  0.000343  0.000343  0.284847  0.000343  0.000343
# 11997  0.000343  0.000343  0.000343  0.000343  0.284847  0.000343  0.000343
# 11998  0.000343  0.000343  0.000343  0.000343  0.284847  0.000343  0.000343
# 11999  0.000343  0.000343  0.000343  0.000343  0.284847  0.000343  0.000343
#
#               7
# 0      0.500000
# 1      0.500000
# 2      0.499454
# 3      0.499454
# 4      0.498908
# ...         ...
# 11995  0.000343
# 11996  0.000343
# 11997  0.000343
# 11998  0.000343
# 11999  0.000343
#
# [12000 rows x 8 columns]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df.to_csv('/content/drive/MyDrive/Colab Notebooks/Engergy_drl_e1.csv')

# %%
#Run Baseline Model
dqn = build_agent(model, actions)
dqn.compile(Adam(lr=1e-3), metrics=['mae'])
dqn.fit(env_bsl, nb_steps=12000, visualize=False, verbose=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Training for 12000 steps ...
# Interval 1 (0 steps performed)
#     1/10000 [..............................] - ETA: 12:04 - reward: 0.5000
# /usr/local/lib/python3.7/dist-packages/keras/engine/training_v1.py:2079: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# /usr/local/lib/python3.7/dist-packages/rl/memory.py:37: UserWarning: Not enough entries to sample without replacement. Consider increasing your warm-up phase to avoid oversampling!
#   warnings.warn('Not enough entries to sample without replacement. Consider increasing your warm-up phase to avoid oversampling!')
# 10000/10000 [==============================] - 96s 10ms/step - reward: 0.3933
# 10 episodes - episode_reward: 393.269 [392.681, 393.684] - loss: 0.213 - mae: 13.231 - mean_q: 15.386
#
# Interval 2 (10000 steps performed)
#  1996/10000 [====>.........................] - ETA: 1:06 - reward: 0.3924done, took 112.847 seconds

# %%
sscores = dqn.test(env_bsl, nb_episodes = 100, visualize = False)
# Out:
# Testing for 100 episodes ...
# Episode 1: reward: 252.078, steps: 1000
# Episode 2: reward: 252.078, steps: 1000
# Episode 3: reward: 252.078, steps: 1000
# Episode 4: reward: 252.078, steps: 1000
# Episode 5: reward: 252.078, steps: 1000
# Episode 6: reward: 252.078, steps: 1000
# Episode 7: reward: 252.078, steps: 1000
# Episode 8: reward: 252.078, steps: 1000
# Episode 9: reward: 252.078, steps: 1000
# Episode 10: reward: 252.078, steps: 1000
# Episode 11: reward: 252.078, steps: 1000
# Episode 12: reward: 252.078, steps: 1000
# Episode 13: reward: 252.078, steps: 1000
# Episode 14: reward: 252.078, steps: 1000
# Episode 15: reward: 252.078, steps: 1000
# Episode 16: reward: 252.078, steps: 1000
# Episode 17: reward: 252.078, steps: 1000
# Episode 18: reward: 252.078, steps: 1000
# Episode 19: reward: 252.078, steps: 1000
# Episode 20: reward: 252.078, steps: 1000
# Episode 21: reward: 252.078, steps: 1000
# Episode 22: reward: 252.078, steps: 1000
# Episode 23: reward: 252.078, steps: 1000
# Episode 24: reward: 252.078, steps: 1000
# Episode 25: reward: 252.078, steps: 1000
# Episode 26: reward: 252.078, steps: 1000
# Episode 27: reward: 252.078, steps: 1000
# Episode 28: reward: 252.078, steps: 1000
# Episode 29: reward: 252.078, steps: 1000
# Episode 30: reward: 252.078, steps: 1000
# Episode 31: reward: 252.078, steps: 1000
# Episode 32: reward: 252.078, steps: 1000
# Episode 33: reward: 252.078, steps: 1000
# Episode 34: reward: 252.078, steps: 1000
# Episode 35: reward: 252.078, steps: 1000
# Episode 36: reward: 252.078, steps: 1000
# Episode 37: reward: 252.078, steps: 1000
# Episode 38: reward: 252.078, steps: 1000
# Episode 39: reward: 252.078, steps: 1000
# Episode 40: reward: 252.078, steps: 1000
# Episode 41: reward: 252.078, steps: 1000
# Episode 42: reward: 252.078, steps: 1000
# Episode 43: reward: 252.078, steps: 1000
# Episode 44: reward: 252.078, steps: 1000
# Episode 45: reward: 252.078, steps: 1000
# Episode 46: reward: 252.078, steps: 1000
# Episode 47: reward: 252.078, steps: 1000
# Episode 48: reward: 252.078, steps: 1000
# Episode 49: reward: 252.078, steps: 1000
# Episode 50: reward: 252.078, steps: 1000
# Episode 51: reward: 252.078, steps: 1000
# Episode 52: reward: 252.078, steps: 1000
# Episode 53: reward: 252.078, steps: 1000
# Episode 54: reward: 252.078, steps: 1000
# Episode 55: reward: 252.078, steps: 1000
# Episode 56: reward: 252.078, steps: 1000
# Episode 57: reward: 252.078, steps: 1000
# Episode 58: reward: 252.078, steps: 1000
# Episode 59: reward: 252.078, steps: 1000
# Episode 60: reward: 252.078, steps: 1000
# Episode 61: reward: 252.078, steps: 1000
# Episode 62: reward: 252.078, steps: 1000
# Episode 63: reward: 252.078, steps: 1000
# Episode 64: reward: 252.078, steps: 1000
# Episode 65: reward: 252.078, steps: 1000
# Episode 66: reward: 252.078, steps: 1000
# Episode 67: reward: 252.078, steps: 1000
# Episode 68: reward: 252.078, steps: 1000
# Episode 69: reward: 252.078, steps: 1000
# Episode 70: reward: 252.078, steps: 1000
# Episode 71: reward: 252.078, steps: 1000
# Episode 72: reward: 252.078, steps: 1000
# Episode 73: reward: 252.078, steps: 1000
# Episode 74: reward: 252.078, steps: 1000
# Episode 75: reward: 252.078, steps: 1000
# Episode 76: reward: 252.078, steps: 1000
# Episode 77: reward: 252.078, steps: 1000
# Episode 78: reward: 252.078, steps: 1000
# Episode 79: reward: 252.078, steps: 1000
# Episode 80: reward: 252.078, steps: 1000
# Episode 81: reward: 252.078, steps: 1000
# Episode 82: reward: 252.078, steps: 1000
# Episode 83: reward: 252.078, steps: 1000
# Episode 84: reward: 252.078, steps: 1000
# Episode 85: reward: 252.078, steps: 1000
# Episode 86: reward: 252.078, steps: 1000
# Episode 87: reward: 252.078, steps: 1000
# Episode 88: reward: 252.078, steps: 1000
# Episode 89: reward: 252.078, steps: 1000
# Episode 90: reward: 252.078, steps: 1000
# Episode 91: reward: 252.078, steps: 1000
# Episode 92: reward: 252.078, steps: 1000
# Episode 93: reward: 252.078, steps: 1000
# Episode 94: reward: 252.078, steps: 1000
# Episode 95: reward: 252.078, steps: 1000
# Episode 96: reward: 252.078, steps: 1000
# Episode 97: reward: 252.078, steps: 1000
# Episode 98: reward: 252.078, steps: 1000
# Episode 99: reward: 252.078, steps: 1000
# Episode 100: reward: 252.078, steps: 1000

# %%
len(Network_energy_drl)
# Out:
# 3296000

# %%
len(drl)
# Out:
# 1000

# %%
Arti = np.array(drl)

# %%
pd.DataFrame(Arti).to_csv('/content/drive/MyDrive/Colab Notebooks/packet_e1.csv')

# %%
len(power_drl)
# Out:
# 12000

# %%
Arti1 = np.array(power_drl)

# %%
pd.DataFrame(Arti1).to_csv('/content/drive/MyDrive/Colab Notebooks/total_E_e1.csv')

# %%
len(Network_energy_baseline)
# Out:
# 112000

# %%
#Taking every 1000th sample for plotting in DRL.
res = []
i = 0

while(i < 12000):
    res.append(power_drl[i])
    i += 1000
res.append(power_drl[-1])

# %%
print(res)
# Out:
# [4.0, 3.4910594048000236, 2.953722982400049, 2.4180247808000734, 1.87522762240008, 1.33079224320008, 0.816390912000081, 0.6170740480000815, 0.5744803072000819, 0.535163008000082, 0.5013064448000824, 0.4729106176000827, 0.4374158336000828]

# %%
#Taking every 1000th sample for plotting in Baseline.

res1 = []
i = 0

while(i < 12000):
    res1.append(power_baseline[i])
    i += 1000
    
res1.append(power_baseline[-1])
